# %% [markdown]
# # IMPORT LIBRARIES
# ## panda库简介：https://www.jianshu.com/p/6acafa350208

# %%
imhttp://localhost:8888/notebooks/myProjects/learning_datascience/Ex_Files_DSF_DataMining/Exercise%20Files/Ch4/04_04/DM_04_04.ipynb#panda%E5%BA%93%E7%AE%80%E4%BB%8B%EF%BC%9Ahttps://www.jianshu.com/p/6acafa350208port pandas as pd
import numpy as np
import pylab as pl
from sklearn.neighbors import KNeighborsClassifier

# %matplotlib inline

# %% [markdown]
# # LOAD DATA
# ## Read CSV & list columns

# %%
ccdefault = pd.read_csv('/Users/catfish/myProjects/learning_datascience/Ex_Files_DSF_DataMining/Exercise Files/Ch4/04_04/ccdefault.csv')
list(ccdefault.columns.values)
# Out:
# ['ID',
#  'LIMIT_BAL',
#  'SEX',
#  'EDUCATION',
#  'MARRIAGE',
#  'AGE',
#  'PAY_0',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5',
#  'PAY_6',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6',
#  'DEFAULT']

# %% [markdown]
# ## Create new dataset without ID variable
# ### 出去了ID，也就是第一列之后，剩下的variable存在一个叫ccd的表里

# %%
ccd = ccdefault[ccdefault.columns[1:]]
list(ccd.columns.values)
# Out:
# ['LIMIT_BAL',
#  'SEX',
#  'EDUCATION',
#  'MARRIAGE',
#  'AGE',
#  'PAY_0',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5',
#  'PAY_6',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6',
#  'DEFAULT']

# %% [markdown]
# ## Split data
# ### Cross vaildation，create traning set 2/3 of data，test set 1/3 of data
# ### traning set和test set的数据类型都是Pandas

# %%
test_idx = np.random.uniform(0, 1, len(ccd)) <= .333
train = ccd[test_idx == True]
test = ccd[test_idx == False]

# %%
train.head()
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 2       90000    2          2         2   34      0      0      0      0
# 4       50000    1          2         1   57     -1      0     -1      0
# 5       50000    1          1         2   37      0      0      0      0
# 7      100000    2          2         2   23      0     -1     -1      0
# 11     260000    2          1         2   51     -1     -1     -1     -1
#
#     PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 2       0  ...      14331      14948      15549      1518      1500      1000
# 4       0  ...      20940      19146      19131      2000     36681     10000
# 5       0  ...      19394      19619      20024      2500      1815       657
# 7       0  ...        221       -159        567       380       601         0
# 11     -1  ...       8517      22287      13668     21818      9966      8583
#
#     PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# 2       1000      1000      5000        0
# 4       9000       689       679        0
# 5       1000      1000       800        0
# 7        581      1687      1542        0
# 11     22301         0      3640        0
#
# [5 rows x 24 columns]

# %%
test.tail()
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 29993     100000    1          1         2   38      0     -1     -1      0
# 29995     220000    1          3         1   39      0      0      0      0
# 29996     150000    1          3         2   43     -1     -1     -1     -1
# 29997      30000    1          2         2   37      4      3      2     -1
# 29998      80000    1          3         1   41      1     -1      0      0
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29993      0  ...      70626      69473      55004      2000    111784
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996      0  ...       8979       5190          0      1837      3526
# 29997      0  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# 29993      4000      3000      2000      2000        0
# 29995      5003      3047      5000      1000        0
# 29996      8998       129         0         0        0
# 29997     22000      4200      2000      3100        1
# 29998      1178      1926     52964      1804        1
#
# [5 rows x 24 columns]

# %% [markdown]
# # CLASSIFICATION
# ## Specify features used to predict

# %%
features = [ 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'DEFAULT' ]

# %% [markdown]
# ## Chose n & conduct knn classification

# %%
n = 10 # Neighbors

results = []

clf = KNeighborsClassifier(n_neighbors = n)
clf.fit(train[features], train['DEFAULT'])
preds = clf.predict(test[features])
accuracy = np.where(preds == test['DEFAULT'], 1, 0).sum() / float(len(test))*100

# %% [markdown]
# ## Print accuracy

# %%
print ("Neighbors: %d, Accuracy: %2d%%" % (n, round(accuracy, 2)))
# Out:
# Neighbors: 10, Accuracy: 77%
